# %%
import pandas as pd
import numpy as np
import os
SEED = 42
rng = np.random.default_rng(SEED)

# %%
naps_csv = r"/Users/foramkamdar/Desktop/oehrn_lab/repos/pd_nonmotor/stimuli/all_NAPs_ratings.csv"
df_naps = pd.read_csv(naps_csv)
df = df_naps.copy()
print(df.head())

out_path = r"/Users/foramkamdar/Desktop/oehrn_lab/repos/pd_nonmotor/stimuli/blocks/pdnm002_sessions/future sessions"
# Define parameters
total_sessions = 6
n_trials_per_session = 112
instruction_cue = ["FEEL", "TONE"]

# Define valence bins and labels
bins = [1, 2, 3, 4, 5, 6, 7, 8, 9]
bin_labels = [f"{bins[i]}-{bins[i+1]}" for i in range(len(bins) - 1)]
n_bins = len(bin_labels) # 8

# Check now many images fall into each valence bin
df["val_bin"] = pd.cut(
    df["Valence"],
    bins=bins,
    labels=bin_labels,
    include_lowest=True
)

counts = df["val_bin"].value_counts().reindex(bin_labels)
print(counts)

# Images available for each session for each valence bin
count_per_session = counts // total_sessions
print(count_per_session)
# category of images
cats = df["Category"].unique().tolist()
print("Categories of images:", cats)
n_cats = len(cats)
print("Number of categories:", n_cats) 
# Minimum number of images needed per session for each valence bin
min_trials_per_bin = 14 
min_trials_per_bin_per_session = min_trials_per_bin * total_sessions

# find bins that does not have enough images for each session
bins_insufficient = count_per_session[count_per_session < min_trials_per_bin].index.tolist()
print("Bins with insufficient images for each session:", bins_insufficient)

#set aside insufficient bins for now
df_sufficient = df[~df["val_bin"].isin(bins_insufficient)]
print("Number of images in sufficient bins:", len(df_sufficient))

bins_sufficient = df_sufficient["val_bin"].unique().tolist()
print("Sufficient bins:", bins_sufficient)
# Out:
#               ID Category  Nr V/H Description  Valence  Arousal  Width  \
# 0  Animals_001_h  Animals   1   h  Dead Stork     2.57     6.44   1600
# 1  Animals_002_v  Animals   2   v        Lion     6.24     6.68   1200
# 2  Animals_003_h  Animals   3   h       Snake     5.24     5.52   1600
# 3  Animals_004_v  Animals   4   v        Wolf     4.50     7.02   1200
# 4  Animals_005_h  Animals   5   h         Bat     5.31     5.82   1600
#
#    Height  Luminance  Contrast
# 0    1200     126.05     68.45
# 1    1600     123.41     32.34
# 2    1200     135.28     59.92
# 3    1600     122.15     75.10
# 4    1200     131.81     59.77
# val_bin
# 1-2     22
# 2-3    113
# 3-4    194
# 4-5    200
# 5-6    248
# 6-7    334
# 7-8    229
# 8-9     16
# Name: count, dtype: int64
# val_bin
# 1-2     3
# 2-3    18
# 3-4    32
# 4-5    33
# 5-6    41
# 6-7    55
# 7-8    38
# 8-9     2
# Name: count, dtype: int64
# Categories of images: ['Animals', 'Faces', 'Landscapes', 'Objects', 'People']
# Number of categories: 5
# Bins with insufficient images for each session: ['1-2', '8-9']
# Number of images in sufficient bins: 1318
# Sufficient bins: ['2-3', '6-7', '5-6', '4-5', '3-4', '7-8']

# %%
# import os

# rng = np.random.default_rng(SEED)

# df_work = df.copy()

# df_suff = df_work[df_work["val_bin"].isin(bins_sufficient)].copy()
# df_insuff = df_work[df_work["val_bin"].isin(bins_insufficient)].copy()

# # Shuffle once
# df_suff = df_suff.sample(frac=1, random_state=SEED).reset_index(drop=True)
# df_insuff = df_insuff.sample(frac=1, random_state=SEED).reset_index(drop=True)

# used_ids = set()
# all_blocks = []

# base_per_bin = 14

# def sample_balanced(pool, n_take):
#     """Round-robin category sampling"""
#     result = []
#     cats = pool["Category"].unique().tolist()
#     cat_pools = {c: pool[pool["Category"] == c].copy() for c in cats}

#     # pointers
#     for c in cats:
#         cat_pools[c] = cat_pools[c].reset_index(drop=True)

#     i = 0
#     while len(result) < n_take:
#         c = cats[i % len(cats)]
#         if len(cat_pools[c]) > 0:
#             row = cat_pools[c].iloc[0]
#             result.append(row)
#             cat_pools[c] = cat_pools[c].iloc[1:]
#         i += 1

#     return pd.DataFrame(result)

# for s in range(total_sessions):

#     print(f"\n========== SESSION {s+1} ==========")

#     session_rows = []
#     extra_needed = 0

#     # -------------------------
#     # 1. INSUFFICIENT BINS
#     # -------------------------
#     for b in bins_insufficient:
#         pool = df_insuff[(df_insuff["val_bin"] == b) & (~df_insuff["ID"].isin(used_ids))]

#         take_n = int(np.ceil(len(df_insuff[df_insuff["val_bin"] == b]) / total_sessions))
#         take = pool.head(take_n)

#         print(f"\n[INSUFF BIN {b}] taking {len(take)}")
#         print(take[["ID","Category","val_bin"]])

#         used_ids.update(take["ID"].tolist())
#         session_rows.append(take)

#         deficit = base_per_bin - len(take)
#         if deficit > 0:
#             extra_needed += deficit

#     print(f"\nTotal deficit to redistribute: {extra_needed}")

#     # -------------------------
#     # 2. SUFFICIENT BINS
#     # -------------------------
#     bins_extra_distribution = {b: base_per_bin for b in bins_sufficient}

#     if extra_needed > 0:
#         per_bin_extra = extra_needed // len(bins_sufficient)
#         remainder = extra_needed % len(bins_sufficient)

#         for b in bins_sufficient:
#             bins_extra_distribution[b] += per_bin_extra

#         for b in bins_sufficient[:remainder]:
#             bins_extra_distribution[b] += 1

#     print("\nBin allocation (after redistribution):")
#     print(bins_extra_distribution)

#     # sampling with category balancing
#     for b in bins_sufficient:
#         pool = df_suff[(df_suff["val_bin"] == b) & (~df_suff["ID"].isin(used_ids))]

#         take_n = bins_extra_distribution[b]

#         take = sample_balanced(pool, take_n)

#         print(f"\n[SUFF BIN {b}] taking {len(take)}")
#         print(take[["ID","Category","val_bin"]])

#         used_ids.update(take["ID"].tolist())
#         session_rows.append(take)

#     # -------------------------
#     # 3. COMBINE
#     # -------------------------
#     block = pd.concat(session_rows).reset_index(drop=True)

#     print("\n--- Combined BEFORE condition split ---")
#     print(block.groupby("val_bin").size())

#     # -------------------------
#     # 4. CONDITION SPLIT
#     # -------------------------
#     block["condition"] = None

#     for b in block["val_bin"].unique():
#         idx = block[block["val_bin"] == b].index.tolist()
#         rng.shuffle(idx)

#         half = len(idx) // 2
#         feel_idx = idx[:half]
#         tone_idx = idx[half:]

#         block.loc[feel_idx, "condition"] = "FEEL"
#         block.loc[tone_idx, "condition"] = "TONE"

#     print("\n--- After condition split ---")
#     print(block.groupby(["val_bin","condition"]).size())

#     # -------------------------
#     # 5. RANDOMIZE
#     # -------------------------
#     block = block.sample(frac=1, random_state=SEED + s).reset_index(drop=True)

#     # -------------------------
#     # 6. FINAL FORMAT
#     # -------------------------
#     block["trial"] = np.arange(1, len(block) + 1)
#     block["filename"] = block["ID"] + ".jpg"

#     block = block[["trial","ID","filename","Category","Valence","val_bin","condition"]]

#     # -------------------------
#     # 7. FINAL SUMMARY
#     # -------------------------
#     print("\n=== FINAL SUMMARY ===")
#     print("Total trials:", len(block))
#     print("\nPer bin:")
#     print(block.groupby("val_bin").size())
#     print("\nPer bin x condition:")
#     print(block.groupby(["val_bin","condition"]).size())

#     # -------------------------
#     # 8. SAVE
#     # -------------------------
#     out_csv = os.path.join(out_path, f"session_{s+1}.csv")
#     block.to_csv(out_csv, index=False)

#     print("\nSaved:", out_csv)

#     all_blocks.append(block)

# %%
# import os

# rng = np.random.default_rng(SEED)

# df_work = df.copy()

# df_suff = df_work[df_work["val_bin"].isin(bins_sufficient)].copy()
# df_insuff = df_work[df_work["val_bin"].isin(bins_insufficient)].copy()

# # Shuffle once
# df_suff = df_suff.sample(frac=1, random_state=SEED).reset_index(drop=True)
# df_insuff = df_insuff.sample(frac=1, random_state=SEED).reset_index(drop=True)

# used_ids = set()
# all_blocks = []

# base_per_bin = 14

# # global tracker
# category_usage = {c: 0 for c in cats}

# def sample_balanced(pool, n_take):
#     result = []

#     pool = pool.copy()

#     while len(result) < n_take:
#         # sort categories by least used globally
#         sorted_cats = sorted(category_usage.keys(), key=lambda x: category_usage[x])

#         picked = False

#         for c in sorted_cats:
#             sub = pool[pool["Category"] == c]
#             if len(sub) > 0:
#                 row = sub.iloc[0]
#                 result.append(row)

#                 # update
#                 category_usage[c] += 1
#                 pool = pool.drop(row.name)

#                 picked = True
#                 break

#         if not picked:
#             raise ValueError("Not enough images for category balancing")

#     return pd.DataFrame(result)

# # Precompute insufficient bin distribution
# insuff_distribution = {}

# for b in bins_insufficient:
#     total = len(df_insuff[df_insuff["val_bin"] == b])
#     base = total // total_sessions
#     remainder = total % total_sessions

#     dist = [base] * total_sessions
#     for i in range(remainder):
#         dist[i] += 1

#     rng.shuffle(dist)  # avoid fixed bias
#     insuff_distribution[b] = dist

# print("\nInsufficient bin distribution:", insuff_distribution)

# for s in range(total_sessions):

#     print(f"\n========== SESSION {s+1} ==========")

#     session_rows = []
#     extra_needed = 0

#     # -------------------------
#     # 1. INSUFFICIENT BINS
#     # -------------------------
#     for b in bins_insufficient:
#         pool = df_insuff[(df_insuff["val_bin"] == b) & (~df_insuff["ID"].isin(used_ids))]

#         take_n = insuff_distribution[b][s]
#         take = sample_balanced(pool, b, take_n)

#         print(f"\n[INSUFF BIN {b}] taking {len(take)}")
#         print(take[["ID","Category","val_bin"]])

#         used_ids.update(take["ID"].tolist())
#         session_rows.append(take)

#         deficit = base_per_bin - len(take)
#         if deficit > 0:
#             extra_needed += deficit

#     print(f"\nTotal deficit to redistribute: {extra_needed}")

#     # -------------------------
#     # 2. SUFFICIENT BINS
#     # -------------------------
#     bins_extra_distribution = {b: base_per_bin for b in bins_sufficient}

#     if extra_needed > 0:
#         per_bin_extra = extra_needed // len(bins_sufficient)
#         remainder = extra_needed % len(bins_sufficient)

#     for b in bins_sufficient:
#         bins_extra_distribution[b] += per_bin_extra

#     # ROTATE instead of fixed order
#     rotated_bins = bins_sufficient[s % len(bins_sufficient):] + bins_sufficient[:s % len(bins_sufficient)]

#     for b in rotated_bins[:remainder]:
#         bins_extra_distribution[b] += 1

#     print("\nBin allocation (after redistribution):")
#     print(bins_extra_distribution)

#     # sampling with category balancing
#     for b in bins_sufficient:
#         pool = df_suff[(df_suff["val_bin"] == b) & (~df_suff["ID"].isin(used_ids))]

#         take_n = bins_extra_distribution[b]

#         take = sample_balanced(pool, take_n)

#         print(f"\n[SUFF BIN {b}] taking {len(take)}")
#         print(take[["ID","Category","val_bin"]])

#         used_ids.update(take["ID"].tolist())
#         session_rows.append(take)

#     # -------------------------
#     # 3. COMBINE
#     # -------------------------
#     block = pd.concat(session_rows).reset_index(drop=True)

#     print("\n--- Combined BEFORE condition split ---")
#     print(block.groupby("val_bin").size())

#     # -------------------------
#     # 4. CONDITION SPLIT
#     # -------------------------
#     block["condition"] = None

#     for b in block["val_bin"].unique():
#         idx = block[block["val_bin"] == b].index.tolist()
#         rng.shuffle(idx)

#         half = len(idx) // 2
#         feel_idx = idx[:half]
#         tone_idx = idx[half:]

#         block.loc[feel_idx, "condition"] = "FEEL"
#         block.loc[tone_idx, "condition"] = "TONE"

#     print("\n--- After condition split ---")
#     print(block.groupby(["val_bin","condition"]).size())

#     # -------------------------
#     # 5. RANDOMIZE
#     # -------------------------
#     block = block.sample(frac=1, random_state=SEED + s).reset_index(drop=True)

#     # -------------------------
#     # 6. FINAL FORMAT
#     # -------------------------
#     block["trial"] = np.arange(1, len(block) + 1)
#     block["filename"] = block["ID"] + ".jpg"

#     block = block[["trial","ID","filename","Category","Valence","val_bin","condition"]]

#     # -------------------------
#     # 7. FINAL SUMMARY
#     # -------------------------
#     print("\n=== FINAL SUMMARY ===")
#     print("Total trials:", len(block))
#     print("\nPer bin:")
#     print(block.groupby("val_bin").size())
#     print("\nPer bin x condition:")
#     print(block.groupby(["val_bin","condition"]).size())

#     # -------------------------
#     # 8. SAVE
#     # -------------------------
#     out_csv = os.path.join(out_path, f"session_{s+1}.csv")
#     block.to_csv(out_csv, index=False)

#     print("\nSaved:", out_csv)

#     all_blocks.append(block)

# %%
# #BINS BALANCED: SAFE TO USE. ADDING CATEOGPRY LATER
# SEED = 42
# rng = np.random.default_rng(SEED)

# df_work = df.copy()

# df_suff = df_work[df_work["val_bin"].isin(bins_sufficient)].copy()
# df_insuff = df_work[df_work["val_bin"].isin(bins_insufficient)].copy()

# # Shuffle once
# df_suff = df_suff.sample(frac=1, random_state=SEED).reset_index(drop=True)
# df_insuff = df_insuff.sample(frac=1, random_state=SEED).reset_index(drop=True)

# used_ids = set()
# all_blocks = []

# base_per_bin = 14

# # =========================================================
# # 🔴 FIX 1: PRECOMPUTE INSUFFICIENT BIN DISTRIBUTION
# # =========================================================
# insuff_distribution = {}

# for b in bins_insufficient:
#     total = len(df_insuff[df_insuff["val_bin"] == b])
#     base = total // total_sessions
#     remainder = total % total_sessions

#     dist = [base] * total_sessions
#     for i in range(remainder):
#         dist[i] += 1

#     rng.shuffle(dist)
#     insuff_distribution[b] = dist

# print("\nInsufficient bin distribution:", insuff_distribution)

# # =========================================================
# # 🔴 FIX 2: PER-BIN CATEGORY TRACKING (CRITICAL FIX)
# # =========================================================
# bin_cat_used = {
#     b: {c: 0 for c in cats} for b in bin_labels
# }

# def sample_balanced(pool, b, n_take):
#     result = []
#     pool = pool.copy()

#     while len(result) < n_take:

#         # prioritize least-used category within THIS BIN
#         sorted_cats = sorted(cats, key=lambda c: bin_cat_used[b][c])

#         picked = False

#         for c in sorted_cats:
#             sub = pool[pool["Category"] == c]

#             if len(sub) > 0:
#                 row = sub.iloc[0]

#                 result.append(row)

#                 # update tracker
#                 bin_cat_used[b][c] += 1
#                 pool = pool.drop(row.name)

#                 picked = True
#                 break

#         if not picked:
#             raise ValueError(f"Not enough images for bin {b}")

#     return pd.DataFrame(result)

# # =========================================================
# # MAIN LOOP
# # =========================================================
# for s in range(total_sessions):

#     print(f"\n========== SESSION {s+1} ==========")

#     session_rows = []
#     extra_needed = 0

#     # -------------------------
#     # 1. INSUFFICIENT BINS
#     # -------------------------
#     for b in bins_insufficient:
#         pool = df_insuff[
#             (df_insuff["val_bin"] == b) &
#             (~df_insuff["ID"].isin(used_ids))
#         ]

#         take_n = insuff_distribution[b][s]

#         take = sample_balanced(pool, b, take_n)

#         print(f"\n[INSUFF BIN {b}] taking {len(take)}")
#         print(take[["ID","Category","val_bin"]])

#         used_ids.update(take["ID"].tolist())
#         session_rows.append(take)

#         deficit = base_per_bin - len(take)
#         if deficit > 0:
#             extra_needed += deficit

#     print(f"\nTotal deficit to redistribute: {extra_needed}")

#     # -------------------------
#     # 2. SUFFICIENT BINS
#     # -------------------------
#     bins_extra_distribution = {b: base_per_bin for b in bins_sufficient}

#     if extra_needed > 0:
#         per_bin_extra = extra_needed // len(bins_sufficient)
#         remainder = extra_needed % len(bins_sufficient)

#         for b in bins_sufficient:
#             bins_extra_distribution[b] += per_bin_extra

#         # 🔴 FIX: rotate to remove bias
#         rotated_bins = (
#             bins_sufficient[s % len(bins_sufficient):] +
#             bins_sufficient[:s % len(bins_sufficient)]
#         )

#         for b in rotated_bins[:remainder]:
#             bins_extra_distribution[b] += 1

#     print("\nBin allocation (after redistribution):")
#     print(bins_extra_distribution)

#     # -------------------------
#     # 3. SUFFICIENT BIN SAMPLING
#     # -------------------------
#     for b in bins_sufficient:
#         pool = df_suff[
#             (df_suff["val_bin"] == b) &
#             (~df_suff["ID"].isin(used_ids))
#         ]

#         take_n = bins_extra_distribution[b]

#         take = sample_balanced(pool, b, take_n)

#         print(f"\n[SUFF BIN {b}] taking {len(take)}")
#         print(take[["ID","Category","val_bin"]])

#         used_ids.update(take["ID"].tolist())
#         session_rows.append(take)

#     # -------------------------
#     # 4. COMBINE
#     # -------------------------
#     block = pd.concat(session_rows).reset_index(drop=True)

#     print("\n--- Combined BEFORE condition split ---")
#     print(block.groupby("val_bin").size())

#     # -------------------------
#     # 5. CONDITION SPLIT
#     # -------------------------
#     block["condition"] = None

#     for b in block["val_bin"].unique():
#         idx = block[block["val_bin"] == b].index.tolist()
#         rng.shuffle(idx)

#         half = len(idx) // 2
#         block.loc[idx[:half], "condition"] = "FEEL"
#         block.loc[idx[half:], "condition"] = "TONE"

#     print("\n--- After condition split ---")
#     print(block.groupby(["val_bin","condition"]).size())

#     # -------------------------
#     # 6. RANDOMIZE
#     # -------------------------
#     block = block.sample(frac=1, random_state=SEED + s).reset_index(drop=True)

#     # -------------------------
#     # 7. FINAL FORMAT
#     # -------------------------
#     block["trial"] = np.arange(1, len(block) + 1)
#     block["filename"] = block["ID"] + ".jpg"

#     block = block[
#         ["trial","ID","filename","Category","Valence","val_bin","condition"]
#     ]

#     # -------------------------
#     # 8. FINAL SUMMARY
#     # -------------------------
#     print("\n=== FINAL SUMMARY ===")
#     print("Total trials:", len(block))
#     print("\nPer bin:")
#     print(block.groupby("val_bin").size())
#     print("\nPer bin x condition:")
#     print(block.groupby(["val_bin","condition"]).size())

#     # -------------------------
#     # 9. SAVE
#     # -------------------------
#     out_csv = os.path.join(out_path, f"session_{s+1}.csv")
#     block.to_csv(out_csv, index=False)

#     print("\nSaved:", out_csv)

#     all_blocks.append(block)

# # =========================================================
# # 🔬 FINAL GLOBAL CHECK (IMPORTANT)
# # =========================================================
# all_data = pd.concat(all_blocks)

# print("\n================ GLOBAL CHECK ================")
# print("\nPer bin:")
# print(all_data.groupby("val_bin").size())

# print("\nPer category:")
# print(all_data.groupby("Category").size())

# print("\nPer bin x category:")
# print(all_data.groupby(["val_bin","Category"]).size())

# %%
#BINS BALANCED: SAFE TO USE. no category balancing. Totally random within bins. will be biased like dataset.
SEED = 42
rng = np.random.default_rng(SEED)

df_work = df.copy()

df_suff = df_work[df_work["val_bin"].isin(bins_sufficient)].copy()
df_insuff = df_work[df_work["val_bin"].isin(bins_insufficient)].copy()

# Shuffle once
df_suff = df_suff.sample(frac=1, random_state=SEED).reset_index(drop=True)
df_insuff = df_insuff.sample(frac=1, random_state=SEED).reset_index(drop=True)

used_ids = set()
all_blocks = []

base_per_bin = 14

# =========================================================
#  PRECOMPUTE INSUFFICIENT BIN DISTRIBUTION
# =========================================================
insuff_distribution = {}

for b in bins_insufficient:
    total = len(df_insuff[df_insuff["val_bin"] == b])
    base = total // total_sessions
    remainder = total % total_sessions

    dist = [base] * total_sessions
    for i in range(remainder):
        dist[i] += 1

    rng.shuffle(dist)
    insuff_distribution[b] = dist

print("\nInsufficient bin distribution:", insuff_distribution)



# =========================================================
# MAIN LOOP
# =========================================================
for s in range(total_sessions):

    print(f"\n========== SESSION {s+1} ==========")

    session_rows = []
    extra_needed = 0

    # -------------------------
    # 1. INSUFFICIENT BINS
    # -------------------------
    for b in bins_insufficient:
        pool = df_insuff[
            (df_insuff["val_bin"] == b) &
            (~df_insuff["ID"].isin(used_ids))
        ]

        take_n = insuff_distribution[b][s]

        #take = sample_balanced(pool, b, take_n)
        take = pool.sample(n=take_n, random_state=SEED + s)

        print(f"\n[INSUFF BIN {b}] taking {len(take)}")
        print(take[["ID","Category","val_bin"]])

        used_ids.update(take["ID"].tolist())
        session_rows.append(take)

        deficit = base_per_bin - len(take)
        if deficit > 0:
            extra_needed += deficit

    print(f"\nTotal deficit to redistribute: {extra_needed}")

    # -------------------------
    # 2. SUFFICIENT BINS
    # -------------------------
    bins_extra_distribution = {b: base_per_bin for b in bins_sufficient}

    if extra_needed > 0:
        per_bin_extra = extra_needed // len(bins_sufficient)
        remainder = extra_needed % len(bins_sufficient)

        for b in bins_sufficient:
            bins_extra_distribution[b] += per_bin_extra

        # 🔴 FIX: rotate to remove bias
        rotated_bins = (
            bins_sufficient[s % len(bins_sufficient):] +
            bins_sufficient[:s % len(bins_sufficient)]
        )

        for b in rotated_bins[:remainder]:
            bins_extra_distribution[b] += 1

    print("\nBin allocation (after redistribution):")
    print(bins_extra_distribution)

    # -------------------------
    # 3. SUFFICIENT BIN SAMPLING
    # -------------------------
    for b in bins_sufficient:
        pool = df_suff[
            (df_suff["val_bin"] == b) &
            (~df_suff["ID"].isin(used_ids))
        ]

        take_n = bins_extra_distribution[b]

        take = pool.sample(n=take_n, random_state=SEED + s)

        print(f"\n[SUFF BIN {b}] taking {len(take)}")
        print(take[["ID","Category","val_bin"]])

        used_ids.update(take["ID"].tolist())
        session_rows.append(take)

    # -------------------------
    # 4. COMBINE
    # -------------------------
    block = pd.concat(session_rows).reset_index(drop=True)

    print("\n--- Combined BEFORE condition split ---")
    print(block.groupby("val_bin").size())

    # -------------------------
    # 5. CONDITION SPLIT
    # -------------------------
    block["condition"] = None

    for b in block["val_bin"].unique():
        idx = block[block["val_bin"] == b].index.tolist()
        rng.shuffle(idx)

        half = len(idx) // 2
        block.loc[idx[:half], "condition"] = "FEEL"
        block.loc[idx[half:], "condition"] = "TONE"

    print("\n--- After condition split ---")
    print(block.groupby(["val_bin","condition"]).size())

    # -------------------------
    # 6. RANDOMIZE
    # -------------------------
    block = block.sample(frac=1, random_state=SEED + s).reset_index(drop=True)

    # -------------------------
    # 7. FINAL FORMAT
    # -------------------------
    block["trial"] = np.arange(1, len(block) + 1)
    block["filename"] = block["ID"] + ".jpg"

    block = block[
        ["trial","ID","filename","Category","Valence","val_bin","condition"]
    ]

    # -------------------------
    # 8. FINAL SUMMARY
    # -------------------------
    print("\n=== FINAL SUMMARY ===")
    print("Total trials:", len(block))
    print("\nPer bin:")
    print(block.groupby("val_bin").size())
    print("\nPer bin x condition:")
    print(block.groupby(["val_bin","condition"]).size())

    # -------------------------
    # 9. SAVE
    # -------------------------
    out_csv = os.path.join(out_path, f"session_{s+1}.csv")
    block.to_csv(out_csv, index=False)

    print("\nSaved:", out_csv)

    all_blocks.append(block)

# =========================================================
# 🔬 FINAL GLOBAL CHECK (IMPORTANT)
# =========================================================
all_data = pd.concat(all_blocks)

print("\n================ GLOBAL CHECK ================")
print("\nPer bin:")
print(all_data.groupby("val_bin").size())

print("\nPer category:")
print(all_data.groupby("Category").size())

print("\nPer bin x category:")
print(all_data.groupby(["val_bin","Category"]).size())
# Out:
# Insufficient bin distribution: {'1-2': [4, 4, 3, 3, 4, 4], '8-9': [3, 2, 3, 3, 3, 2]}
#
# ========== SESSION 1 ==========
#
# [INSUFF BIN 1-2] taking 4
#               ID Category val_bin
# 0   People_227_h   People     1-2
# 22  People_246_h   People     1-2
# 16  People_226_h   People     1-2
# 1   People_240_h   People     1-2
#
# [INSUFF BIN 8-9] taking 3
#                   ID    Category val_bin
# 2      Animals_220_h     Animals     8-9
# 3   Landscapes_120_v  Landscapes     8-9
# 12  Landscapes_154_h  Landscapes     8-9
#
# Total deficit to redistribute: 21
#
# Bin allocation (after redistribution):
# {'2-3': 18, '6-7': 18, '5-6': 18, '4-5': 17, '3-4': 17, '7-8': 17}
#
# [SUFF BIN 2-3] taking 18
#                  ID Category val_bin
# 836   Animals_077_h  Animals     2-3
# 55      Faces_016_h    Faces     2-3
# 444    People_200_h   People     2-3
# 772   Animals_042_h  Animals     2-3
# 85     People_136_h   People     2-3
# 526   Animals_048_h  Animals     2-3
# 775   Animals_039_h  Animals     2-3
# 759    People_020_h   People     2-3
# 538    People_003_h   People     2-3
# 87      Faces_018_h    Faces     2-3
# 1079   People_222_h   People     2-3
# 413   Objects_157_h  Objects     2-3
# 887   Objects_011_h  Objects     2-3
# 1299   People_133_h   People     2-3
# 167   Objects_285_h  Objects     2-3
# 4      People_205_v   People     2-3
# 782   Animals_025_h  Animals     2-3
# 232     Faces_145_v    Faces     2-3
#
# [SUFF BIN 6-7] taking 18
#                     ID    Category val_bin
# 120      Objects_085_h     Objects     6-7
# 1236     Animals_192_h     Animals     6-7
# 322       People_099_h      People     6-7
# 819   Landscapes_082_v  Landscapes     6-7
# 264   Landscapes_018_h  Landscapes     6-7
# 1174  Landscapes_065_h  Landscapes     6-7
# 1140       Faces_064_h       Faces     6-7
# 747      Animals_198_h     Animals     6-7
# 878      Animals_162_h     Animals     6-7
# 824   Landscapes_108_v  Landscapes     6-7
# 326        Faces_072_h       Faces     6-7
# 37        People_029_h      People     6-7
# 1274     Animals_170_h     Animals     6-7
# 522   Landscapes_085_h  Landscapes     6-7
# 1080  Landscapes_107_h  Landscapes     6-7
# 565      Objects_028_v     Objects     6-7
# 464       People_173_h      People     6-7
# 624      Objects_324_h     Objects     6-7
#
# [SUFF BIN 5-6] taking 18
#                  ID Category val_bin
# 227   Objects_308_h  Objects     5-6
# 53      Faces_250_h    Faces     5-6
# 986     Faces_048_h    Faces     5-6
# 517   Animals_028_h  Animals     5-6
# 861   Animals_043_h  Animals     5-6
# 1296   People_100_h   People     5-6
# 1032    Faces_030_h    Faces     5-6
# 603   Objects_166_h  Objects     5-6
# 79    Objects_309_h  Objects     5-6
# 1229    Faces_308_h    Faces     5-6
# 1212  Objects_172_v  Objects     5-6
# 1233  Objects_307_v  Objects     5-6
# 1248    Faces_054_v    Faces     5-6
# 978   Objects_119_h  Objects     5-6
# 409    People_114_h   People     5-6
# 879   Objects_296_h  Objects     5-6
# 1027   People_150_h   People     5-6
# 109     Faces_320_v    Faces     5-6
#
# [SUFF BIN 4-5] taking 17
#                     ID    Category val_bin
# 563      Objects_228_h     Objects     4-5
# 65       Objects_005_h     Objects     4-5
# 164        Faces_024_h       Faces     4-5
# 1019       Faces_299_h       Faces     4-5
# 774      Animals_111_h     Animals     4-5
# 675        Faces_160_v       Faces     4-5
# 373      Animals_086_v     Animals     4-5
# 1121      People_234_h      People     4-5
# 1148      People_170_v      People     4-5
# 256      Objects_282_h     Objects     4-5
# 358        Faces_220_h       Faces     4-5
# 1202  Landscapes_032_v  Landscapes     4-5
# 1072      People_203_v      People     4-5
# 440      Animals_004_v     Animals     4-5
# 1224  Landscapes_012_h  Landscapes     4-5
# 1168     Objects_215_v     Objects     4-5
# 296        Faces_168_h       Faces     4-5
#
# [SUFF BIN 3-4] taking 17
#                     ID    Category val_bin
# 948      Objects_150_h     Objects     3-4
# 94       Objects_154_h     Objects     3-4
# 1081      People_129_h      People     3-4
# 674      Objects_284_h     Objects     3-4
# 479      Objects_023_v     Objects     3-4
# 1064      People_023_h      People     3-4
# 396       People_071_h      People     3-4
# 82        People_058_h      People     3-4
# 770      Objects_328_h     Objects     3-4
# 769      Objects_135_h     Objects     3-4
# 1278      People_070_v      People     3-4
# 107       People_006_h      People     3-4
# 579        Faces_033_h       Faces     3-4
# 44       Animals_045_h     Animals     3-4
# 1136  Landscapes_177_h  Landscapes     3-4
# 799      Objects_148_h     Objects     3-4
# 483      Objects_233_h     Objects     3-4
#
# [SUFF BIN 7-8] taking 17
#                     ID    Category val_bin
# 1254  Landscapes_125_h  Landscapes     7-8
# 369        Faces_114_h       Faces     7-8
# 60    Landscapes_088_v  Landscapes     7-8
# 1115       Faces_131_v       Faces     7-8
# 105   Landscapes_133_h  Landscapes     7-8
# 1142      People_116_h      People     7-8
# 169   Landscapes_128_h  Landscapes     7-8
# 1119       Faces_260_h       Faces     7-8
# 870   Landscapes_110_v  Landscapes     7-8
# 707        Faces_133_h       Faces     7-8
# 1244       Faces_080_h       Faces     7-8
# 138   Landscapes_124_h  Landscapes     7-8
# 533   Landscapes_102_h  Landscapes     7-8
# 1020      People_181_v      People     7-8
# 1281       Faces_350_h       Faces     7-8
# 792   Landscapes_140_v  Landscapes     7-8
# 838       People_108_h      People     7-8
#
# --- Combined BEFORE condition split ---
# val_bin
# 1-2     4
# 2-3    18
# 3-4    17
# 4-5    17
# 5-6    18
# 6-7    18
# 7-8    17
# 8-9     3
# dtype: int64
#
# --- After condition split ---
# val_bin  condition
# 1-2      FEEL         2
#          TONE         2
# 2-3      FEEL         9
#          TONE         9
# 3-4      FEEL         8
#          TONE         9
# 4-5      FEEL         8
#          TONE         9
# 5-6      FEEL         9
#          TONE         9
# 6-7      FEEL         9
#          TONE         9
# 7-8      FEEL         8
#          TONE         9
# 8-9      FEEL         1
#          TONE         2
# dtype: int64
#
# === FINAL SUMMARY ===
# Total trials: 112
#
# Per bin:
# val_bin
# 1-2     4
# 2-3    18
# 3-4    17
# 4-5    17
# 5-6    18
# 6-7    18
# 7-8    17
# 8-9     3
# dtype: int64
#
# Per bin x condition:
# val_bin  condition
# 1-2      FEEL         2
#          TONE         2
# 2-3      FEEL         9
#          TONE         9
# 3-4      FEEL         8
#          TONE         9
# 4-5      FEEL         8
#          TONE         9
# 5-6      FEEL         9
#          TONE         9
# 6-7      FEEL         9
#          TONE         9
# 7-8      FEEL         8
#          TONE         9
# 8-9      FEEL         1
#          TONE         2
# dtype: int64
#
# Saved: /Users/foramkamdar/Desktop/oehrn_lab/repos/pd_nonmotor/stimuli/blocks/pdnm002_sessions/future sessions/session_1.csv
#
# ========== SESSION 2 ==========
#
# [INSUFF BIN 1-2] taking 4
#                ID Category val_bin
# 30   People_221_h   People     1-2
# 21  Animals_074_h  Animals     1-2
# 20    Faces_371_v    Faces     1-2
# 37   People_211_v   People     1-2
#
# [INSUFF BIN 8-9] taking 2
#                ID Category val_bin
# 23   People_110_h   People     8-9
# 27  Animals_177_h  Animals     8-9
#
# Total deficit to redistribute: 22
#
# Bin allocation (after redistribution):
# {'2-3': 17, '6-7': 18, '5-6': 18, '4-5': 18, '3-4': 18, '7-8': 17}
#
# [SUFF BIN 2-3] taking 17
#                  ID Category val_bin
# 225   Objects_144_h  Objects     2-3
# 43      Faces_032_h    Faces     2-3
# 181     Faces_028_h    Faces     2-3
# 261    People_204_v   People     2-3
# 740     Faces_283_h    Faces     2-3
# 763     Faces_019_h    Faces     2-3
# 884   Animals_016_h  Animals     2-3
# 801   Animals_019_h  Animals     2-3
# 141     Faces_363_v    Faces     2-3
# 1053    Faces_284_h    Faces     2-3
# 111   Animals_033_h  Animals     2-3
# 545    People_119_h   People     2-3
# 1074  Animals_038_h  Animals     2-3
# 16    Objects_132_h  Objects     2-3
# 1111   People_199_v   People     2-3
# 154    People_233_h   People     2-3
# 75     People_142_h   People     2-3
#
# [SUFF BIN 6-7] taking 18
#                     ID    Category val_bin
# 199       People_027_h      People     6-7
# 1156  Landscapes_119_h  Landscapes     6-7
# 1152       Faces_004_h       Faces     6-7
# 704      Objects_290_h     Objects     6-7
# 725       People_194_h      People     6-7
# 315        Faces_101_h       Faces     6-7
# 1218     Objects_260_h     Objects     6-7
# 1204  Landscapes_149_h  Landscapes     6-7
# 1040       Faces_357_v       Faces     6-7
# 927      Objects_032_v     Objects     6-7
# 74         Faces_323_h       Faces     6-7
# 1265     Animals_094_h     Animals     6-7
# 849      Objects_091_h     Objects     6-7
# 629      Animals_107_h     Animals     6-7
# 308      Objects_261_h     Objects     6-7
# 650   Landscapes_184_h  Landscapes     6-7
# 91         Faces_117_h       Faces     6-7
# 606      Animals_097_h     Animals     6-7
#
# [SUFF BIN 5-6] taking 18
#                     ID    Category val_bin
# 808        Faces_057_h       Faces     5-6
# 493   Landscapes_044_h  Landscapes     5-6
# 798        Faces_183_v       Faces     5-6
# 695   Landscapes_091_h  Landscapes     5-6
# 1003  Landscapes_084_v  Landscapes     5-6
# 850      Objects_250_h     Objects     5-6
# 121      Objects_026_v     Objects     5-6
# 1163  Landscapes_083_h  Landscapes     5-6
# 431      Objects_168_v     Objects     5-6
# 881      Objects_274_h     Objects     5-6
# 144      Objects_049_h     Objects     5-6
# 97    Landscapes_081_h  Landscapes     5-6
# 1203     Objects_203_v     Objects     5-6
# 647        Faces_040_h       Faces     5-6
# 618      Animals_085_h     Animals     5-6
# 982      Animals_005_h     Animals     5-6
# 24        People_138_h      People     5-6
# 840      Objects_068_v     Objects     5-6
#
# [SUFF BIN 4-5] taking 18
#                     ID    Category val_bin
# 649        Faces_177_v       Faces     4-5
# 588      Objects_164_h     Objects     4-5
# 77         Faces_215_v       Faces     4-5
# 50         Faces_216_h       Faces     4-5
# 626       People_066_v      People     4-5
# 478      Animals_069_h     Animals     4-5
# 790        Faces_171_v       Faces     4-5
# 8        Animals_081_h     Animals     4-5
# 395      Animals_142_h     Animals     4-5
# 640        Faces_161_h       Faces     4-5
# 362      Objects_116_v     Objects     4-5
# 101       People_122_h      People     4-5
# 486   Landscapes_181_h  Landscapes     4-5
# 1109       Faces_038_h       Faces     4-5
# 1        Objects_222_h     Objects     4-5
# 473   Landscapes_058_h  Landscapes     4-5
# 1312     Objects_287_h     Objects     4-5
# 1272  Landscapes_020_h  Landscapes     4-5
#
# [SUFF BIN 3-4] taking 18
#                     ID    Category val_bin
# 521   Landscapes_070_h  Landscapes     3-4
# 1217     Animals_041_h     Animals     3-4
# 130        Faces_369_v       Faces     3-4
# 46       Animals_065_h     Animals     3-4
# 1282      People_206_h      People     3-4
# 778       People_033_h      People     3-4
# 885        Faces_303_h       Faces     3-4
# 5          Faces_274_h       Faces     3-4
# 319        Faces_270_h       Faces     3-4
# 736      Objects_206_h     Objects     3-4
# 814        Faces_155_h       Faces     3-4
# 139   Landscapes_017_h  Landscapes     3-4
# 598      Objects_110_v     Objects     3-4
# 218       People_228_h      People     3-4
# 2     Landscapes_030_v  Landscapes     3-4
# 288        Faces_148_h       Faces     3-4
# 1046      People_217_h      People     3-4
# 449   Landscapes_011_h  Landscapes     3-4
#
# [SUFF BIN 7-8] taking 17
#                     ID    Category val_bin
# 69         Faces_130_h       Faces     7-8
# 698   Landscapes_137_h  Landscapes     7-8
# 542      Objects_081_h     Objects     7-8
# 206   Landscapes_138_h  Landscapes     7-8
# 543        Faces_321_h       Faces     7-8
# 415      Objects_180_v     Objects     7-8
# 1058     Animals_160_h     Animals     7-8
# 329        Faces_079_h       Faces     7-8
# 381   Landscapes_147_h  Landscapes     7-8
# 327       People_189_h      People     7-8
# 847       People_103_h      People     7-8
# 797        Faces_232_h       Faces     7-8
# 1116      People_051_h      People     7-8
# 541   Landscapes_096_h  Landscapes     7-8
# 468       People_050_v      People     7-8
# 145        Faces_337_h       Faces     7-8
# 235      Animals_179_h     Animals     7-8
#
# --- Combined BEFORE condition split ---
# val_bin
# 1-2     4
# 2-3    17
# 3-4    18
# 4-5    18
# 5-6    18
# 6-7    18
# 7-8    17
# 8-9     2
# dtype: int64
#
# --- After condition split ---
# val_bin  condition
# 1-2      FEEL         2
#          TONE         2
# 2-3      FEEL         8
#          TONE         9
# 3-4      FEEL         9
#          TONE         9
# 4-5      FEEL         9
#          TONE         9
# 5-6      FEEL         9
#          TONE         9
# 6-7      FEEL         9
#          TONE         9
# 7-8      FEEL         8
#          TONE         9
# 8-9      FEEL         1
#          TONE         1
# dtype: int64
#
# === FINAL SUMMARY ===
# Total trials: 112
#
# Per bin:
# val_bin
# 1-2     4
# 2-3    17
# 3-4    18
# 4-5    18
# 5-6    18
# 6-7    18
# 7-8    17
# 8-9     2
# dtype: int64
#
# Per bin x condition:
# val_bin  condition
# 1-2      FEEL         2
#          TONE         2
# 2-3      FEEL         8
#          TONE         9
# 3-4      FEEL         9
#          TONE         9
# 4-5      FEEL         9
#          TONE         9
# 5-6      FEEL         9
#          TONE         9
# 6-7      FEEL         9
#          TONE         9
# 7-8      FEEL         8
#          TONE         9
# 8-9      FEEL         1
#          TONE         1
# dtype: int64
#
# Saved: /Users/foramkamdar/Desktop/oehrn_lab/repos/pd_nonmotor/stimuli/blocks/pdnm002_sessions/future sessions/session_2.csv
#
# ========== SESSION 3 ==========
#
# [INSUFF BIN 1-2] taking 3
#                ID Category val_bin
# 15    Faces_365_v    Faces     1-2
# 25   People_218_v   People     1-2
# 17  Animals_056_h  Animals     1-2
#
# [INSUFF BIN 8-9] taking 3
#                   ID    Category val_bin
# 32      People_113_h      People     8-9
# 29      People_172_v      People     8-9
# 10  Landscapes_165_h  Landscapes     8-9
#
# Total deficit to redistribute: 22
#
# Bin allocation (after redistribution):
# {'2-3': 17, '6-7': 17, '5-6': 18, '4-5': 18, '3-4': 18, '7-8': 18}
#
# [SUFF BIN 2-3] taking 17
#                  ID Category val_bin
# 996   Objects_283_h  Objects     2-3
# 892     Faces_007_h    Faces     2-3
# 710     Faces_147_v    Faces     2-3
# 1100  Animals_054_h  Animals     2-3
# 84    Animals_024_h  Animals     2-3
# 143    People_213_v   People     2-3
# 664    People_243_h   People     2-3
# 779    People_202_h   People     2-3
# 1069    Faces_010_h    Faces     2-3
# 1306   People_039_v   People     2-3
# 865     Faces_366_h    Faces     2-3
# 88    Objects_002_h  Objects     2-3
# 1199   People_127_h   People     2-3
# 1159   People_143_h   People     2-3
# 20    Objects_007_h  Objects     2-3
# 604   Objects_149_h  Objects     2-3
# 476   Animals_068_h  Animals     2-3
#
# [SUFF BIN 6-7] taking 17
#                     ID    Category val_bin
# 909      Objects_321_h     Objects     6-7
# 263      Animals_174_h     Animals     6-7
# 363   Landscapes_100_h  Landscapes     6-7
# 997        Faces_098_h       Faces     6-7
# 158        Faces_310_v       Faces     6-7
# 822        Faces_335_h       Faces     6-7
# 66         Faces_094_h       Faces     6-7
# 662      Objects_092_v     Objects     6-7
# 860        Faces_343_h       Faces     6-7
# 1246       Faces_243_v       Faces     6-7
# 108      Objects_082_h     Objects     6-7
# 172        Faces_067_h       Faces     6-7
# 872       People_153_h      People     6-7
# 732        Faces_085_h       Faces     6-7
# 942      Objects_044_v     Objects     6-7
# 323   Landscapes_041_h  Landscapes     6-7
# 1157      People_178_h      People     6-7
#
# [SUFF BIN 5-6] taking 18
#                     ID    Category val_bin
# 854      Objects_289_h     Objects     5-6
# 971      Objects_062_h     Objects     5-6
# 1095       Faces_297_h       Faces     5-6
# 1181     Objects_302_h     Objects     5-6
# 567      Objects_208_h     Objects     5-6
# 410      Objects_087_h     Objects     5-6
# 1207     Objects_047_h     Objects     5-6
# 972      Objects_178_v     Objects     5-6
# 356      Objects_221_h     Objects     5-6
# 276      Animals_150_h     Animals     5-6
# 458      Animals_006_v     Animals     5-6
# 86       Animals_044_h     Animals     5-6
# 340   Landscapes_040_h  Landscapes     5-6
# 47       Objects_278_h     Objects     5-6
# 614      Objects_269_h     Objects     5-6
# 1132       Faces_251_v       Faces     5-6
# 502        Faces_058_h       Faces     5-6
# 1294     Animals_022_h     Animals     5-6
#
# [SUFF BIN 4-5] taking 18
#                     ID    Category val_bin
# 711       People_164_h      People     4-5
# 28         Faces_006_h       Faces     4-5
# 1192     Objects_281_h     Objects     4-5
# 1304     Animals_133_h     Animals     4-5
# 58       Objects_035_h     Objects     4-5
# 576   Landscapes_003_v  Landscapes     4-5
# 213      Objects_286_h     Objects     4-5
# 511        Faces_157_h       Faces     4-5
# 210      Animals_110_h     Animals     4-5
# 1220       Faces_166_h       Faces     4-5
# 1249     Objects_238_h     Objects     4-5
# 841       People_065_h      People     4-5
# 648   Landscapes_013_v  Landscapes     4-5
# 789       People_076_h      People     4-5
# 324      Objects_242_h     Objects     4-5
# 229        Faces_029_h       Faces     4-5
# 846   Landscapes_024_v  Landscapes     4-5
# 447      Objects_147_v     Objects     4-5
#
# [SUFF BIN 3-4] taking 18
#                     ID    Category val_bin
# 590       People_094_h      People     3-4
# 23        People_245_v      People     3-4
# 1234       Faces_280_h       Faces     3-4
# 1315      People_219_h      People     3-4
# 80       Animals_060_h     Animals     3-4
# 757        Faces_279_h       Faces     3-4
# 300   Landscapes_005_h  Landscapes     3-4
# 1048     Objects_235_h     Objects     3-4
# 273       People_147_h      People     3-4
# 1025     Objects_145_h     Objects     3-4
# 1184      People_137_h      People     3-4
# 1266     Objects_140_h     Objects     3-4
# 1139     Objects_126_h     Objects     3-4
# 597      Objects_232_h     Objects     3-4
# 471        Faces_012_v       Faces     3-4
# 330   Landscapes_001_h  Landscapes     3-4
# 839        Faces_288_h       Faces     3-4
# 568   Landscapes_014_h  Landscapes     3-4
#
# [SUFF BIN 7-8] taking 18
#                     ID    Category val_bin
# 303        Faces_091_v       Faces     7-8
# 1205  Landscapes_103_v  Landscapes     7-8
# 67        People_107_h      People     7-8
# 452        Faces_227_v       Faces     7-8
# 305        Faces_235_v       Faces     7-8
# 287        Faces_088_v       Faces     7-8
# 684        Faces_228_h       Faces     7-8
# 750      Animals_173_h     Animals     7-8
# 949       People_111_h      People     7-8
# 25        People_183_h      People     7-8
# 756       People_067_h      People     7-8
# 1215     Animals_137_h     Animals     7-8
# 1297       Faces_061_h       Faces     7-8
# 426        Faces_361_v       Faces     7-8
# 1243  Landscapes_143_h  Landscapes     7-8
# 525        Faces_122_h       Faces     7-8
# 594      Objects_326_h     Objects     7-8
# 102       People_026_h      People     7-8
#
# --- Combined BEFORE condition split ---
# val_bin
# 1-2     3
# 2-3    17
# 3-4    18
# 4-5    18
# 5-6    18
# 6-7    17
# 7-8    18
# 8-9     3
# dtype: int64
#
# --- After condition split ---
# val_bin  condition
# 1-2      FEEL         1
#          TONE         2
# 2-3      FEEL         8
#          TONE         9
# 3-4      FEEL         9
#          TONE         9
# 4-5      FEEL         9
#          TONE         9
# 5-6      FEEL         9
#          TONE         9
# 6-7      FEEL         8
#          TONE         9
# 7-8      FEEL         9
#          TONE         9
# 8-9      FEEL         1
#          TONE         2
# dtype: int64
#
# === FINAL SUMMARY ===
# Total trials: 112
#
# Per bin:
# val_bin
# 1-2     3
# 2-3    17
# 3-4    18
# 4-5    18
# 5-6    18
# 6-7    17
# 7-8    18
# 8-9     3
# dtype: int64
#
# Per bin x condition:
# val_bin  condition
# 1-2      FEEL         1
#          TONE         2
# 2-3      FEEL         8
#          TONE         9
# 3-4      FEEL         9
#          TONE         9
# 4-5      FEEL         9
#          TONE         9
# 5-6      FEEL         9
#          TONE         9
# 6-7      FEEL         8
#          TONE         9
# 7-8      FEEL         9
#          TONE         9
# 8-9      FEEL         1
#          TONE         2
# dtype: int64
#
# Saved: /Users/foramkamdar/Desktop/oehrn_lab/repos/pd_nonmotor/stimuli/blocks/pdnm002_sessions/future sessions/session_3.csv
#
# ========== SESSION 4 ==========
#
# [INSUFF BIN 1-2] taking 3
#               ID Category val_bin
# 6    Faces_143_v    Faces     1-2
# 26  People_238_h   People     1-2
# 31   Faces_367_h    Faces     1-2
#
# [INSUFF BIN 8-9] taking 3
#                   ID    Category val_bin
# 24     Animals_166_v     Animals     8-9
# 13  Landscapes_116_v  Landscapes     8-9
# 9   Landscapes_141_h  Landscapes     8-9
#
# Total deficit to redistribute: 22
#
# Bin allocation (after redistribution):
# {'2-3': 18, '6-7': 17, '5-6': 17, '4-5': 18, '3-4': 18, '7-8': 18}
#
# [SUFF BIN 2-3] taking 18
#                     ID    Category val_bin
# 201        Faces_170_h       Faces     2-3
# 562       People_197_h      People     2-3
# 1226      People_001_h      People     2-3
# 787        Faces_153_v       Faces     2-3
# 760   Landscapes_007_h  Landscapes     2-3
# 1055      People_009_h      People     2-3
# 830      Objects_003_h     Objects     2-3
# 438       People_239_h      People     2-3
# 556       People_215_h      People     2-3
# 434       People_016_h      People     2-3
# 906       People_235_h      People     2-3
# 788        Faces_293_h       Faces     2-3
# 57         Faces_152_h       Faces     2-3
# 1014     Objects_125_h     Objects     2-3
# 212       People_242_v      People     2-3
# 1147       Faces_031_v       Faces     2-3
# 76       Animals_067_h     Animals     2-3
# 237       People_013_v      People     2-3
#
# [SUFF BIN 6-7] taking 17
#                     ID    Category val_bin
# 706      Objects_061_h     Objects     6-7
# 632       People_177_h      People     6-7
# 73        People_248_h      People     6-7
# 1298     Objects_198_h     Objects     6-7
# 1149      People_158_h      People     6-7
# 21    Landscapes_127_h  Landscapes     6-7
# 688      Objects_195_v     Objects     6-7
# 1008     Objects_042_h     Objects     6-7
# 10       Animals_215_v     Animals     6-7
# 1108       Faces_240_h       Faces     6-7
# 712        Faces_263_v       Faces     6-7
# 259      Objects_254_h     Objects     6-7
# 491   Landscapes_145_h  Landscapes     6-7
# 858        Faces_184_h       Faces     6-7
# 17        People_064_h      People     6-7
# 871        Faces_332_v       Faces     6-7
# 175      Objects_301_h     Objects     6-7
#
# [SUFF BIN 5-6] taking 17
#                     ID    Category val_bin
# 364        Faces_223_v       Faces     5-6
# 692      Animals_082_h     Animals     5-6
# 313      Objects_231_h     Objects     5-6
# 454      Objects_312_h     Objects     5-6
# 239      Objects_297_h     Objects     5-6
# 155      Objects_279_h     Objects     5-6
# 1208       Faces_194_h       Faces     5-6
# 572      Animals_083_h     Animals     5-6
# 51       Objects_313_h     Objects     5-6
# 359        Faces_119_v       Faces     5-6
# 921        Faces_222_h       Faces     5-6
# 1011      People_184_h      People     5-6
# 1033     Objects_027_h     Objects     5-6
# 277      Objects_031_h     Objects     5-6
# 482   Landscapes_037_v  Landscapes     5-6
# 1180       Faces_312_h       Faces     5-6
# 1107     Objects_303_h     Objects     5-6
#
# [SUFF BIN 4-5] taking 18
#                     ID    Category val_bin
# 530   Landscapes_056_h  Landscapes     4-5
# 7        Objects_181_h     Objects     4-5
# 386      Animals_141_h     Animals     4-5
# 1137     Objects_224_h     Objects     4-5
# 642      Objects_225_h     Objects     4-5
# 917       People_146_h      People     4-5
# 298      Objects_105_h     Objects     4-5
# 856      Objects_293_h     Objects     4-5
# 1219       Faces_015_h       Faces     4-5
# 32       Objects_131_h     Objects     4-5
# 686      Objects_133_h     Objects     4-5
# 268      Animals_143_h     Animals     4-5
# 762   Landscapes_077_v  Landscapes     4-5
# 1227  Landscapes_067_h  Landscapes     4-5
# 200      Objects_210_h     Objects     4-5
# 936        Faces_275_h       Faces     4-5
# 503      Objects_234_h     Objects     4-5
# 34       Animals_079_h     Animals     4-5
#
# [SUFF BIN 3-4] taking 18
#                     ID    Category val_bin
# 3        Animals_050_h     Animals     3-4
# 361      Objects_088_h     Objects     3-4
# 466      Objects_229_h     Objects     3-4
# 834        Faces_163_h       Faces     3-4
# 1042     Animals_018_h     Animals     3-4
# 780        Faces_271_h       Faces     3-4
# 1286     Objects_218_h     Objects     3-4
# 31    Landscapes_004_h  Landscapes     3-4
# 802       People_072_v      People     3-4
# 488       People_223_h      People     3-4
# 913      Objects_318_h     Objects     3-4
# 1044     Objects_170_v     Objects     3-4
# 1277  Landscapes_066_h  Landscapes     3-4
# 1084      People_073_v      People     3-4
# 687        Faces_011_h       Faces     3-4
# 1237     Objects_006_h     Objects     3-4
# 1185       Faces_272_h       Faces     3-4
# 115      Animals_084_h     Animals     3-4
#
# [SUFF BIN 7-8] taking 18
#                     ID    Category val_bin
# 219   Landscapes_034_h  Landscapes     7-8
# 0     Landscapes_097_v  Landscapes     7-8
# 226      Animals_172_h     Animals     7-8
# 991      Objects_080_h     Objects     7-8
# 1195     Objects_037_h     Objects     7-8
# 27        People_154_h      People     7-8
# 292      Animals_161_h     Animals     7-8
# 1087     Animals_163_h     Animals     7-8
# 1183  Landscapes_174_h  Landscapes     7-8
# 1037     Objects_096_v     Objects     7-8
# 1252  Landscapes_153_h  Landscapes     7-8
# 492       People_168_h      People     7-8
# 726      Animals_186_h     Animals     7-8
# 112       People_195_h      People     7-8
# 977       People_055_h      People     7-8
# 1206     Animals_101_v     Animals     7-8
# 1124     Objects_171_h     Objects     7-8
# 251   Landscapes_162_h  Landscapes     7-8
#
# --- Combined BEFORE condition split ---
# val_bin
# 1-2     3
# 2-3    18
# 3-4    18
# 4-5    18
# 5-6    17
# 6-7    17
# 7-8    18
# 8-9     3
# dtype: int64
#
# --- After condition split ---
# val_bin  condition
# 1-2      FEEL         1
#          TONE         2
# 2-3      FEEL         9
#          TONE         9
# 3-4      FEEL         9
#          TONE         9
# 4-5      FEEL         9
#          TONE         9
# 5-6      FEEL         8
#          TONE         9
# 6-7      FEEL         8
#          TONE         9
# 7-8      FEEL         9
#          TONE         9
# 8-9      FEEL         1
#          TONE         2
# dtype: int64
#
# === FINAL SUMMARY ===
# Total trials: 112
#
# Per bin:
# val_bin
# 1-2     3
# 2-3    18
# 3-4    18
# 4-5    18
# 5-6    17
# 6-7    17
# 7-8    18
# 8-9     3
# dtype: int64
#
# Per bin x condition:
# val_bin  condition
# 1-2      FEEL         1
#          TONE         2
# 2-3      FEEL         9
#          TONE         9
# 3-4      FEEL         9
#          TONE         9
# 4-5      FEEL         9
#          TONE         9
# 5-6      FEEL         8
#          TONE         9
# 6-7      FEEL         8
#          TONE         9
# 7-8      FEEL         9
#          TONE         9
# 8-9      FEEL         1
#          TONE         2
# dtype: int64
#
# Saved: /Users/foramkamdar/Desktop/oehrn_lab/repos/pd_nonmotor/stimuli/blocks/pdnm002_sessions/future sessions/session_4.csv
#
# ========== SESSION 5 ==========
#
# [INSUFF BIN 1-2] taking 4
#               ID Category val_bin
# 34  People_038_h   People     1-2
# 5   People_201_v   People     1-2
# 11   Faces_364_v    Faces     1-2
# 7   People_208_h   People     1-2
#
# [INSUFF BIN 8-9] taking 3
#                   ID    Category val_bin
# 33  Landscapes_180_h  Landscapes     8-9
# 14  Landscapes_183_h  Landscapes     8-9
# 19       Faces_109_v       Faces     8-9
#
# Total deficit to redistribute: 21
#
# Bin allocation (after redistribution):
# {'2-3': 18, '6-7': 17, '5-6': 17, '4-5': 17, '3-4': 18, '7-8': 18}
#
# [SUFF BIN 2-3] taking 18
#                     ID    Category val_bin
# 207   Landscapes_002_h  Landscapes     2-3
# 1259      People_019_v      People     2-3
# 320       People_008_h      People     2-3
# 222   Landscapes_022_h  Landscapes     2-3
# 548      Animals_062_h     Animals     2-3
# 398        Faces_009_h       Faces     2-3
# 382       People_002_v      People     2-3
# 1264      People_225_h      People     2-3
# 332       People_021_h      People     2-3
# 72        People_140_h      People     2-3
# 730      Animals_071_h     Animals     2-3
# 481      Animals_013_h     Animals     2-3
# 505        Faces_149_v       Faces     2-3
# 132       People_004_h      People     2-3
# 420   Landscapes_139_h  Landscapes     2-3
# 635       People_144_h      People     2-3
# 651       People_022_h      People     2-3
# 810       People_241_h      People     2-3
#
# [SUFF BIN 6-7] taking 17
#                     ID    Category val_bin
# 36       Animals_104_h     Animals     6-7
# 128      Objects_205_h     Objects     6-7
# 96         Faces_083_h       Faces     6-7
# 157      Objects_102_v     Objects     6-7
# 1285     Animals_194_h     Animals     6-7
# 925       People_063_h      People     6-7
# 311      Objects_300_h     Objects     6-7
# 610        Faces_236_h       Faces     6-7
# 932        Faces_056_h       Faces     6-7
# 970   Landscapes_075_h  Landscapes     6-7
# 1242       Faces_123_h       Faces     6-7
# 1007  Landscapes_150_v  Landscapes     6-7
# 805      Objects_075_h     Objects     6-7
# 952      Objects_072_v     Objects     6-7
# 291        Faces_259_v       Faces     6-7
# 1051     Animals_185_h     Animals     6-7
# 425      Objects_267_v     Objects     6-7
#
# [SUFF BIN 5-6] taking 17
#                     ID    Category val_bin
# 721      Objects_090_h     Objects     5-6
# 641      Animals_121_h     Animals     5-6
# 78    Landscapes_046_h  Landscapes     5-6
# 1096      People_095_h      People     5-6
# 392      Objects_258_h     Objects     5-6
# 585   Landscapes_019_h  Landscapes     5-6
# 1284     Objects_200_h     Objects     5-6
# 1036     Objects_204_h     Objects     5-6
# 859      Objects_161_v     Objects     5-6
# 574      Objects_209_h     Objects     5-6
# 191      Objects_245_h     Objects     5-6
# 465        Faces_211_h       Faces     5-6
# 551      Animals_199_h     Animals     5-6
# 771      Animals_190_h     Animals     5-6
# 1130      People_155_h      People     5-6
# 445      Objects_241_h     Objects     5-6
# 244      Animals_058_h     Animals     5-6
#
# [SUFF BIN 4-5] taking 17
#                     ID    Category val_bin
# 103        Faces_039_h       Faces     4-5
# 1230     Animals_066_h     Animals     4-5
# 258      Objects_216_h     Objects     4-5
# 197      Objects_251_v     Objects     4-5
# 342      Objects_236_h     Objects     4-5
# 312      Objects_107_h     Objects     4-5
# 806   Landscapes_015_h  Landscapes     4-5
# 281        Faces_162_h       Faces     4-5
# 1235       Faces_167_v       Faces     4-5
# 299      Objects_146_h     Objects     4-5
# 124        Faces_266_h       Faces     4-5
# 815       People_131_h      People     4-5
# 968        Faces_156_h       Faces     4-5
# 113      Objects_124_h     Objects     4-5
# 182      Animals_072_h     Animals     4-5
# 417      Objects_108_v     Objects     4-5
# 636        Faces_023_h       Faces     4-5
#
# [SUFF BIN 3-4] taking 18
#                     ID    Category val_bin
# 735       People_212_h      People     3-4
# 253        Faces_302_h       Faces     3-4
# 1190     Objects_106_v     Objects     3-4
# 475       People_098_h      People     3-4
# 507       People_126_h      People     3-4
# 474      Objects_017_v     Objects     3-4
# 974      Objects_109_h     Objects     3-4
# 140   Landscapes_025_h  Landscapes     3-4
# 682      Objects_158_h     Objects     3-4
# 380       People_090_v      People     3-4
# 534        Faces_370_h       Faces     3-4
# 1094      People_124_h      People     3-4
# 547      Objects_111_h     Objects     3-4
# 231        Faces_291_h       Faces     3-4
# 1288       Faces_298_h       Faces     3-4
# 399   Landscapes_010_h  Landscapes     3-4
# 737        Faces_287_h       Faces     3-4
# 1000      People_087_h      People     3-4
#
# [SUFF BIN 7-8] taking 18
#                     ID    Category val_bin
# 367       People_112_h      People     7-8
# 217        Faces_136_v       Faces     7-8
# 937       People_192_h      People     7-8
# 669        Faces_115_h       Faces     7-8
# 243       People_187_h      People     7-8
# 390   Landscapes_134_h  Landscapes     7-8
# 52        People_196_h      People     7-8
# 634        Faces_066_h       Faces     7-8
# 749      Objects_192_h     Objects     7-8
# 1307     Animals_090_h     Animals     7-8
# 1292  Landscapes_173_h  Landscapes     7-8
# 118        Faces_340_h       Faces     7-8
# 910        Faces_002_v       Faces     7-8
# 581       People_130_h      People     7-8
# 776        Faces_356_h       Faces     7-8
# 694   Landscapes_142_h  Landscapes     7-8
# 742        Faces_124_h       Faces     7-8
# 421        Faces_106_h       Faces     7-8
#
# --- Combined BEFORE condition split ---
# val_bin
# 1-2     4
# 2-3    18
# 3-4    18
# 4-5    17
# 5-6    17
# 6-7    17
# 7-8    18
# 8-9     3
# dtype: int64
#
# --- After condition split ---
# val_bin  condition
# 1-2      FEEL         2
#          TONE         2
# 2-3      FEEL         9
#          TONE         9
# 3-4      FEEL         9
#          TONE         9
# 4-5      FEEL         8
#          TONE         9
# 5-6      FEEL         8
#          TONE         9
# 6-7      FEEL         8
#          TONE         9
# 7-8      FEEL         9
#          TONE         9
# 8-9      FEEL         1
#          TONE         2
# dtype: int64
#
# === FINAL SUMMARY ===
# Total trials: 112
#
# Per bin:
# val_bin
# 1-2     4
# 2-3    18
# 3-4    18
# 4-5    17
# 5-6    17
# 6-7    17
# 7-8    18
# 8-9     3
# dtype: int64
#
# Per bin x condition:
# val_bin  condition
# 1-2      FEEL         2
#          TONE         2
# 2-3      FEEL         9
#          TONE         9
# 3-4      FEEL         9
#          TONE         9
# 4-5      FEEL         8
#          TONE         9
# 5-6      FEEL         8
#          TONE         9
# 6-7      FEEL         8
#          TONE         9
# 7-8      FEEL         9
#          TONE         9
# 8-9      FEEL         1
#          TONE         2
# dtype: int64
#
# Saved: /Users/foramkamdar/Desktop/oehrn_lab/repos/pd_nonmotor/stimuli/blocks/pdnm002_sessions/future sessions/session_5.csv
#
# ========== SESSION 6 ==========
#
# [INSUFF BIN 1-2] taking 4
#               ID Category val_bin
# 4   People_220_h   People     1-2
# 18  People_198_h   People     1-2
# 28  People_237_h   People     1-2
# 35   Faces_159_h    Faces     1-2
#
# [INSUFF BIN 8-9] taking 2
#                   ID    Category val_bin
# 8       People_190_h      People     8-9
# 36  Landscapes_123_h  Landscapes     8-9
#
# Total deficit to redistribute: 22
#
# Bin allocation (after redistribution):
# {'2-3': 18, '6-7': 18, '5-6': 18, '4-5': 17, '3-4': 17, '7-8': 18}
#
# [SUFF BIN 2-3] taking 18
#                  ID Category val_bin
# 529   Animals_057_h  Animals     2-3
# 1178    Faces_368_h    Faces     2-3
# 667    People_118_h   People     2-3
# 1070  Animals_027_h  Animals     2-3
# 176   Animals_032_h  Animals     2-3
# 520    People_082_h   People     2-3
# 411    People_216_h   People     2-3
# 738    People_125_h   People     2-3
# 807   Animals_063_h  Animals     2-3
# 709   Animals_001_h  Animals     2-3
# 708     Faces_174_h    Faces     2-3
# 375    People_075_v   People     2-3
# 915    People_209_v   People     2-3
# 310    People_017_h   People     2-3
# 786    People_031_v   People     2-3
# 1001    Faces_362_v    Faces     2-3
# 1150    Faces_172_h    Faces     2-3
# 1031  Objects_001_h  Objects     2-3
#
# [SUFF BIN 6-7] taking 18
#                     ID    Category val_bin
# 42    Landscapes_086_v  Landscapes     6-7
# 938        Faces_347_h       Faces     6-7
# 135        Faces_044_h       Faces     6-7
# 149      Animals_089_v     Animals     6-7
# 1214     Animals_205_h     Animals     6-7
# 272        Faces_097_v       Faces     6-7
# 302      Objects_030_v     Objects     6-7
# 385        Faces_141_v       Faces     6-7
# 617   Landscapes_092_h  Landscapes     6-7
# 92    Landscapes_048_h  Landscapes     6-7
# 804       People_167_h      People     6-7
# 658        Faces_327_v       Faces     6-7
# 433        Faces_095_h       Faces     6-7
# 1135     Animals_146_h     Animals     6-7
# 1310       Faces_254_h       Faces     6-7
# 403        Faces_111_h       Faces     6-7
# 318        Faces_186_h       Faces     6-7
# 13         Faces_239_v       Faces     6-7
#
# [SUFF BIN 5-6] taking 18
#                     ID    Category val_bin
# 19         Faces_071_v       Faces     5-6
# 611        Faces_233_v       Faces     5-6
# 365        Faces_201_v       Faces     5-6
# 1317      People_042_h      People     5-6
# 941       People_102_h      People     5-6
# 685        Faces_319_v       Faces     5-6
# 1270     Animals_014_h     Animals     5-6
# 524      Animals_026_h     Animals     5-6
# 795      Objects_167_v     Objects     5-6
# 589      Objects_176_v     Objects     5-6
# 537      Animals_046_h     Animals     5-6
# 170      Objects_020_h     Objects     5-6
# 1251     Animals_164_h     Animals     5-6
# 980      Animals_200_v     Animals     5-6
# 345   Landscapes_080_h  Landscapes     5-6
# 100      Objects_310_h     Objects     5-6
# 920      Animals_088_h     Animals     5-6
# 663   Landscapes_130_h  Landscapes     5-6
#
# [SUFF BIN 4-5] taking 17
#                     ID    Category val_bin
# 294       People_060_v      People     4-5
# 61       Objects_138_h     Objects     4-5
# 1114  Landscapes_043_h  Landscapes     4-5
# 114       People_014_h      People     4-5
# 48       Animals_052_v     Animals     4-5
# 14        People_018_h      People     4-5
# 922      Objects_213_h     Objects     4-5
# 470      Objects_122_h     Objects     4-5
# 230      Objects_226_h     Objects     4-5
# 627      Objects_060_h     Objects     4-5
# 184        Faces_154_h       Faces     4-5
# 393   Landscapes_033_h  Landscapes     4-5
# 690       People_061_h      People     4-5
# 1153  Landscapes_061_h  Landscapes     4-5
# 693      Animals_151_v     Animals     4-5
# 1065     Objects_202_h     Objects     4-5
# 131        Faces_197_v       Faces     4-5
#
# [SUFF BIN 3-4] taking 17
#                     ID    Category val_bin
# 41        People_086_h      People     3-4
# 423       People_232_h      People     3-4
# 62       Objects_275_v     Objects     3-4
# 1166  Landscapes_068_h  Landscapes     3-4
# 1049      People_210_h      People     3-4
# 436      Objects_155_h     Objects     3-4
# 220       People_117_h      People     3-4
# 180      Objects_212_h     Objects     3-4
# 621      Objects_143_h     Objects     3-4
# 146        Faces_003_h       Faces     3-4
# 1164      People_123_h      People     3-4
# 890      Objects_207_h     Objects     3-4
# 1090      People_037_h      People     3-4
# 987       People_120_h      People     3-4
# 376        Faces_269_v       Faces     3-4
# 608      Animals_034_h     Animals     3-4
# 1172      People_134_h      People     3-4
#
# [SUFF BIN 7-8] taking 18
#                     ID    Category val_bin
# 90         Faces_349_h       Faces     7-8
# 11       Animals_189_v     Animals     7-8
# 813   Landscapes_114_v  Landscapes     7-8
# 929        Faces_234_h       Faces     7-8
# 1162      People_052_h      People     7-8
# 39         Faces_342_h       Faces     7-8
# 159      Animals_131_h     Animals     7-8
# 1228      People_068_h      People     7-8
# 374      Animals_132_h     Animals     7-8
# 1062     Objects_327_h     Objects     7-8
# 195      Animals_158_h     Animals     7-8
# 188   Landscapes_151_h  Landscapes     7-8
# 462   Landscapes_038_h  Landscapes     7-8
# 513   Landscapes_164_h  Landscapes     7-8
# 845   Landscapes_021_h  Landscapes     7-8
# 18        People_193_h      People     7-8
# 995        Faces_127_h       Faces     7-8
# 873   Landscapes_094_h  Landscapes     7-8
#
# --- Combined BEFORE condition split ---
# val_bin
# 1-2     4
# 2-3    18
# 3-4    17
# 4-5    17
# 5-6    18
# 6-7    18
# 7-8    18
# 8-9     2
# dtype: int64
#
# --- After condition split ---
# val_bin  condition
# 1-2      FEEL         2
#          TONE         2
# 2-3      FEEL         9
#          TONE         9
# 3-4      FEEL         8
#          TONE         9
# 4-5      FEEL         8
#          TONE         9
# 5-6      FEEL         9
#          TONE         9
# 6-7      FEEL         9
#          TONE         9
# 7-8      FEEL         9
#          TONE         9
# 8-9      FEEL         1
#          TONE         1
# dtype: int64
#
# === FINAL SUMMARY ===
# Total trials: 112
#
# Per bin:
# val_bin
# 1-2     4
# 2-3    18
# 3-4    17
# 4-5    17
# 5-6    18
# 6-7    18
# 7-8    18
# 8-9     2
# dtype: int64
#
# Per bin x condition:
# val_bin  condition
# 1-2      FEEL         2
#          TONE         2
# 2-3      FEEL         9
#          TONE         9
# 3-4      FEEL         8
#          TONE         9
# 4-5      FEEL         8
#          TONE         9
# 5-6      FEEL         9
#          TONE         9
# 6-7      FEEL         9
#          TONE         9
# 7-8      FEEL         9
#          TONE         9
# 8-9      FEEL         1
#          TONE         1
# dtype: int64
#
# Saved: /Users/foramkamdar/Desktop/oehrn_lab/repos/pd_nonmotor/stimuli/blocks/pdnm002_sessions/future sessions/session_6.csv
#
# ================ GLOBAL CHECK ================
#
# Per bin:
# val_bin
# 1-2     22
# 2-3    106
# 3-4    106
# 4-5    105
# 5-6    106
# 6-7    105
# 7-8    106
# 8-9     16
# dtype: int64
#
# Per category:
# Category
# Animals        98
# Faces         165
# Landscapes     97
# Objects       157
# People        155
# dtype: int64
#
# Per bin x category:
# val_bin  Category
# 1-2      Animals        2
#          Faces          6
#          People        14
# 2-3      Animals       21
#          Faces         24
#          Landscapes     4
#          Objects       12
#          People        45
# 3-4      Animals        8
#          Faces         22
#          Landscapes    13
#          Objects       31
#          People        32
# 4-5      Animals       15
#          Faces         25
#          Landscapes    15
#          Objects       36
#          People        14
# 5-6      Animals       20
#          Faces         22
#          Landscapes    11
#          Objects       44
#          People         9
# 6-7      Animals       15
#          Faces         34
#          Landscapes    18
#          Objects       25
#          People        13
# 7-8      Animals       14
#          Faces         31
#          Landscapes    28
#          Objects        9
#          People        24
# 8-9      Animals        3
#          Faces          1
#          Landscapes     8
#          People         4
# dtype: int64

# %%
# # cell 3 # #BINS BALANCED: SAFE TO USE. soft category balancing within bins. 

# df_work = df.copy()

# df_suff = df_work[df_work["val_bin"].isin(bins_sufficient)].copy()
# df_insuff = df_work[df_work["val_bin"].isin(bins_insufficient)].copy()

# # Shuffle once
# df_suff = df_suff.sample(frac=1, random_state=SEED).reset_index(drop=True)
# df_insuff = df_insuff.sample(frac=1, random_state=SEED).reset_index(drop=True)

# used_ids = set()
# all_blocks = []

# base_per_bin = 14

# # =========================================================
# #  PRECOMPUTE INSUFFICIENT BIN DISTRIBUTION
# # =========================================================
# insuff_distribution = {}

# for b in bins_insufficient:
#     total = len(df_insuff[df_insuff["val_bin"] == b])
#     base = total // total_sessions
#     remainder = total % total_sessions

#     dist = [base] * total_sessions
#     for i in range(remainder):
#         dist[i] += 1

#     rng.shuffle(dist)
#     insuff_distribution[b] = dist

# print("\nInsufficient bin distribution:", insuff_distribution)


# def soft_category_sample(pool, n_take, seed):
#     rng_local = np.random.default_rng(seed)

#     # shuffle pool first
#     pool = pool.sample(frac=1, random_state=seed).copy()

#     # group by category
#     cat_groups = {
#         c: pool[pool["Category"] == c].copy()
#         for c in pool["Category"].unique()
#     }

#     # shuffle each category
#     for c in cat_groups:
#         cat_groups[c] = cat_groups[c].sample(frac=1, random_state=seed)

#     result = []

#     # round-robin pick (SOFT, not forced)
#     while len(result) < n_take:
#         progressed = False

#         for c in list(cat_groups.keys()):
#             if len(cat_groups[c]) > 0:
#                 row = cat_groups[c].iloc[0]
#                 result.append(row)

#                 cat_groups[c] = cat_groups[c].iloc[1:]
#                 progressed = True

#                 if len(result) == n_take:
#                     break

#         if not progressed:
#             break  # no more data

#     return pd.DataFrame(result)



# # =========================================================
# # MAIN LOOP
# # =========================================================
# for s in range(total_sessions):

#     print(f"\n========== SESSION {s+1} ==========")

#     session_rows = []
#     extra_needed = 0

#     # -------------------------
#     # 1. INSUFFICIENT BINS
#     # -------------------------
#     for b in bins_insufficient:
#         pool = df_insuff[
#             (df_insuff["val_bin"] == b) &
#             (~df_insuff["ID"].isin(used_ids))
#         ]

#         take_n = insuff_distribution[b][s]

#         take = soft_category_sample(pool, take_n, SEED + s)

#         print(f"\n[INSUFF BIN {b}] taking {len(take)}")
#         print(take[["ID","Category","val_bin"]])

#         used_ids.update(take["ID"].tolist())
#         session_rows.append(take)

#         deficit = base_per_bin - len(take)
#         if deficit > 0:
#             extra_needed += deficit

#     print(f"\nTotal deficit to redistribute: {extra_needed}")

#     # -------------------------
#     # 2. SUFFICIENT BINS
#     # -------------------------
#     bins_extra_distribution = {b: base_per_bin for b in bins_sufficient}

#     if extra_needed > 0:
#         per_bin_extra = extra_needed // len(bins_sufficient)
#         remainder = extra_needed % len(bins_sufficient)

#         for b in bins_sufficient:
#             bins_extra_distribution[b] += per_bin_extra

#         # 🔴 FIX: rotate to remove bias
#         rotated_bins = (
#             bins_sufficient[s % len(bins_sufficient):] +
#             bins_sufficient[:s % len(bins_sufficient)]
#         )

#         for b in rotated_bins[:remainder]:
#             bins_extra_distribution[b] += 1

#     print("\nBin allocation (after redistribution):")
#     print(bins_extra_distribution)

#     # -------------------------
#     # 3. SUFFICIENT BIN SAMPLING
#     # -------------------------
#     for b in bins_sufficient:
#         pool = df_suff[
#             (df_suff["val_bin"] == b) &
#             (~df_suff["ID"].isin(used_ids))
#         ]

#         take_n = bins_extra_distribution[b]

#         take = soft_category_sample(pool, take_n, SEED + s)

#         print(f"\n[SUFF BIN {b}] taking {len(take)}")
#         print(take[["ID","Category","val_bin"]])

#         used_ids.update(take["ID"].tolist())
#         session_rows.append(take)

#     # -------------------------
#     # 4. COMBINE
#     # -------------------------
#     block = pd.concat(session_rows).reset_index(drop=True)

#     print("\n--- Combined BEFORE condition split ---")
#     print(block.groupby("val_bin").size())

#     # -------------------------
#     # 5. CONDITION SPLIT
#     # -------------------------
#     block["condition"] = None

#     for b in block["val_bin"].unique():
#         idx = block[block["val_bin"] == b].index.tolist()
#         rng.shuffle(idx)

#         half = len(idx) // 2
#         block.loc[idx[:half], "condition"] = "FEEL"
#         block.loc[idx[half:], "condition"] = "TONE"

#     print("\n--- After condition split ---")
#     print(block.groupby(["val_bin","condition"]).size())

#     # -------------------------
#     # 6. RANDOMIZE
#     # -------------------------
#     block = block.sample(frac=1, random_state=SEED + s).reset_index(drop=True)

#     # -------------------------
#     # 7. FINAL FORMAT
#     # -------------------------
#     block["trial"] = np.arange(1, len(block) + 1)
#     block["filename"] = block["ID"] + ".jpg"

#     block = block[
#         ["trial","ID","filename","Category","Valence","val_bin","condition"]
#     ]

#     # -------------------------
#     # 8. FINAL SUMMARY
#     # -------------------------
#     print("\n=== FINAL SUMMARY ===")
#     print("Total trials:", len(block))
#     print("\nPer bin:")
#     print(block.groupby("val_bin").size())
#     print("\nPer bin x condition:")
#     print(block.groupby(["val_bin","condition"]).size())

#     # -------------------------
#     # 9. SAVE
#     # -------------------------
#     out_csv = os.path.join(out_path, f"session_{s+1}.csv")
#     block.to_csv(out_csv, index=False)

#     print("\nSaved:", out_csv)

#     all_blocks.append(block)

# # =========================================================
# # 🔬 FINAL GLOBAL CHECK (IMPORTANT)
# # =========================================================
# all_data = pd.concat(all_blocks)

# print("\n================ GLOBAL CHECK ================")
# print("\nPer bin:")
# print(all_data.groupby("val_bin").size())

# print("\nPer category:")
# print(all_data.groupby("Category").size())

# print("\nPer bin x category:")
# print(all_data.groupby(["val_bin","Category"]).size())
